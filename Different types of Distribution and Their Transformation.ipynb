# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
df=sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.histplot(df['sepal_length'],kde=True)
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(df['sepal_width'],kde=True)
# Out:
# <Axes: xlabel='sepal_width', ylabel='Count'>

# %%
sns.histplot(df['petal_length'],kde=True)
# Out:
# <Axes: xlabel='petal_length', ylabel='Count'>

# %%
sns.histplot(df['petal_width'],kde=True)
# Out:
# <Axes: xlabel='petal_width', ylabel='Count'>

# %%
## create a normal distributed data
s=np.random.normal(0.5,0.2,1000)
s
# Out:
# array([ 0.34713398,  0.83106088,  0.5817843 ,  0.44105584,  0.68610192,
#         0.64485865,  0.37471573,  0.31704302,  0.70794099,  0.4604427 ,
#         0.3138565 ,  0.54784617,  0.75708533,  0.40648499,  0.20899193,
#         0.72040412,  0.5625743 , -0.00641138,  0.28002121,  0.60573297,
#         0.49484535,  0.82286638,  0.39042742,  0.60917627,  0.82722114,
#         0.4865637 ,  0.17048344,  0.54123325,  0.63934382,  0.61972929,
#         0.58603821,  0.49317137,  0.51666326,  0.16421428, -0.00836862,
#         0.39084865, -0.02631559,  0.66373685,  0.5225224 ,  0.38008751,
#         0.33509859,  0.92139064,  0.39710603,  0.37755007,  0.37168294,
#         0.75557261,  0.31801093,  0.74730431,  0.52722262,  0.45053245,
#         0.76302149,  0.62668148,  0.49921732,  0.5530332 ,  0.64136133,
#         0.59537709,  0.48351973,  0.49142606,  0.36335621,  0.35204688,
#         0.35680549,  0.69605413,  0.63585227,  1.00243498,  0.78644665,
# ...

# %% [markdown]
# # normal distribution

# %%
sns.histplot(s,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# # Log Normal Distribution,Power Law Distribution

# %%
mu, sigma = 3., 1. # mean and standard deviation
s = np.random.lognormal(mu, sigma, 1000)

# %%
sns.histplot(s,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(np.log(s),kde=True)  ##converting it into normal distribution using loge
# Out:
# <Axes: ylabel='Count'>

# %%
## to check whether feature is guassian or normal distributed
## Q-Q plot
import matplotlib.pyplot as plt
import scipy.stats as stat
import pylab
def plot_data(sample):
    plt.figure(figsize=(10,6))
    plt.subplot(1,2,1)
    sns.histplot(sample)
    plt.subplot(1,2,2)
    stat.probplot(sample,dist='norm',plot=pylab)
    plt.show()

# %%
## create a normal distributed data
s=np.random.normal(0.5,0.2,1000)
plot_data(s)

# %%
plot_data(df['sepal_width'])  #also checking for sepal width feature

# %%
##its clear ,it is a normal distribution

# %%
mu, sigma = 3., 1. # mean and standard deviation
sample = np.random.lognormal(mu, sigma, 100)

# %%
def plot_data_log(sample):   ##for checking log normal distribution
    plt.figure(figsize=(10,6))
    plt.subplot(1,2,1)
    sns.histplot(sample)
    plt.subplot(1,2,2)
    stat.probplot(np.log(sample),dist='norm',plot=pylab)
    plt.show()

# %%
plot_data_log(sample)

# %% [markdown]
# # ##Pearson and Sperman Rank Correlation

# %%
df=sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import pandas as pd

# %%
df.corr(numeric_only=True)
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.pairplot(df)
